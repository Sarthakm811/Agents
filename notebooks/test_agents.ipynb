# %%
import sys
sys.path.append("..")
from agents.domain_agent import DomainAwareAgent

# %%
agent = DomainAwareAgent("Deep Learning")
test_cases = [
    "Deep learning improves diagnostic accuracy",
    "Neural networks require clinical validation",
    "AI algorithms show promise in medical imaging"
]

for text in test_cases:
    result = agent.run(f"Check: {text}")
    print(f"Input: {text}")
    print(f"Result: {result['output']}")
    print("-" * 50)

# %%
physics_agent = DomainAwareAgent("Quantum Physics")
physics_text = "Quantum entanglement shows clinical applications"
result = physics_agent.run(f"Check: {physics_text}")
print(result["output"])
